# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### IMAGE BASICS
# #### what’s a pixel?
# Every image consists of a set of pixels. Pixels are the raw building blocks of an image. There is no finer granularity than the pixel.
#
# Normally, we think of a pixel as the “color” or the “inten- sity” of light that appears in a given place in our image.
#
# If we think of an image as a grid, each square in the grid contains a single pixel.
#
# For example, let’s pretend we have an image with a res- olution of 500 × 300. This means that our image is repre- sented as a grid of pixels, with 500 rows and 300 columns. Overall, there are 500 × 300 = 150, 000 pixels in our image.
#
# Most pixels are represented in two ways: grayscale and color. In a grayscale image, each pixel has a value between 0 and 255, where zero corresponds to “black” and 255 cor- responds to “white”. The values in between 0 and 255 are varying shades of gray, where values closer to 0 are darker and values closer to 255 are lighter.
#
# Color pixels are normally represented in the RGB color space – one value for the Red component, one for Green, and one for Blue. Other color spaces exist, but let’s start with the basics and move our way up from there.
#
# Each of the three colors is represented by an integer in the range 0 to 255, which indicates how “much” of the color there is. Given that the pixel value only needs to be in the range [0, 255], we normally use an 8-bit unsigned integer to represent each color intensity.
#
# We then combine these values into an RGB tuple in the form (red, green, blue). This tuple represents our color.
#
# To construct a white color, we would fill up each of the red, green, and blue buckets completely, like this: (255, 255,255).
# Then, to create a black color, we would empty each of the buckets out: (0,0,0).
# To create a pure red color, we would fill up the red bucket (and only the red bucket) up completely: (255,0,0).

# %% [markdown]
# ### Images and Numpy
#
# Numpy can read in certain files types, this includes images stored as arrays.

# %%
from PIL import Image

# %%
pic = Image.open('/content/drive/MyDrive/opencv_logo.png')
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=428x378>

# %%
type(pic)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
pic_arr = np.asarray(pic)
pic_arr.shape
# Out:
# (378, 428, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_arr
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
pic_arr

# %%
pic_frame = pic_arr.copy()
plt.imshow(pic_frame[:,:,0])

# %%
pic_frame = pic_arr.copy()
plt.imshow(pic_frame[:,:,1])

# %%
pic_frame = pic_arr.copy()
plt.imshow(pic_frame[:,:,2])

# %%
pic_red = pic_arr.copy()

# %%
pic_red[:, :, 1] = 0    # Zero out contribution from green
pic_red[:, :, 2] = 0    # Zero out contribution from blue

# %%
plt.imshow(pic_red)

# %%
pic_green = pic_arr.copy()

# %%
pic_green[:, :, 0] = 0    # Zero out contribution from red
pic_green[:, :, 2] = 0    # Zero out contribution from blue

# %%
plt.imshow(pic_green)

# %%
pic_blue = pic_arr.copy()

# %%
pic_blue[:, :, 0] = 0    # Zero out contribution from red
pic_blue[:, :, 1] = 0    # Zero out contribution from green

# %%
plt.imshow(pic_blue)

# %% [markdown]
# ### Read an Image File
#  WARNING! Make sure to provide the correct path, WONT GIVE ERROR! GIVES NONE INSTEAD!!!

# %%
img = cv2.imread("some/wrong/path.jpg")
img

# %%
print(img)
# Out:
# None

# %%
img = cv2.imread('/content/drive/MyDrive/opencv_logo.png')
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
# Shape of an image
img.shape
# Out:
# (378, 428, 3)

# %%
# Type of the array
type(img)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Display an image

# %%
img_bgr = cv2.imread('/content/drive/MyDrive/opencv_logo.png')
plt.imshow(img_bgr) #cv2.imshow

# %%
chess_bgr = cv2.imread('/content/drive/MyDrive/chessboard_mat.jpg')
plt.imshow(chess_bgr)

# %% [markdown]
# The image has been correctly loaded by openCV as a numpy array, but the color of each pixel has been sorted as BGR. Matplotlib's plot expects an RGB image so, for a correct display of the image, it is necessary to swap those channels. This operation can be done either by using openCV conversion functions cv2.cvtColor() or by working directly with the numpy array.

# %%
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
chess_rgb = cv2.cvtColor(chess_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(chess_rgb)

# %% [markdown]
# In RGB color coding colors are modeled as a combination of Red, Green and Blue. But it is a very old color coding. In 1970, two new color codings are developed which are closely aligned with the way human vision actually perceives color.
# HSL - Hue, Saturation and Lightness
# HSV - Hue, Saturation and Value

# %%
img_hls = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HLS)
plt.imshow(img_hls)

# %%
img_hsv = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HSV)
plt.imshow(img_hsv)

# %%
chess_hls = cv2.cvtColor(chess_bgr, cv2.COLOR_BGR2HLS)
plt.imshow(chess_hls)

# %%
chess_hsv = cv2.cvtColor(chess_bgr, cv2.COLOR_BGR2HSV)
plt.imshow(chess_hsv)

# %% [markdown]
# ### Convert RGB to Greyscale

# %%
img_gray = cv2.imread('/content/drive/MyDrive/opencv_logo.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
img_gray = cv2.imread('/content/drive/MyDrive/opencv_logo.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='gray')

# %%
chess_gray = cv2.imread('/content/drive/MyDrive/chessboard_mat.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(chess_gray)

# %%
chess_gray = cv2.imread('/content/drive/MyDrive/chessboard_mat.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(chess_gray, cmap = 'gray')

# %% [markdown]
# ### Saving Image Files

# %%
type(chess_gray)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('grey_chess.jpg',chess_gray)
# Out:
# True

# %% [markdown]
# ## Create blank images

# %%
black_img = np.zeros((512,512,3), np.uint8)
plt.imshow(black_img)

# %%
white_img = np.full((512,512,3),(255,255,255), np.uint8)
plt.imshow(white_img)

# %% [markdown]
# For your reference, here are some common colors repre-
# sented as RGB tuples:
#
# * Black: (0,0,0)
# * White: (255,255,255)
# * Red: (255,0,0)
# * Green: (0,255,0)
# * Blue: (0,0,255)
# * Aqua: (0,255,255)
# * Fuchsia: (255,0,255)
# * Maroon: (128,0,0)
# * Navy: (0,0,128)
# * Olive: (128,128,0)
# * Purple: (128,0,128)
# * Teal: (0,128,128)
# * Yellow: (255,255,0)

# %%
red_img = np.full((512,512,3), (0,255,255), np.uint8)
plt.imshow(red_img)

# %%
white_canvas = np.full((800,800,3),(255,255,255), np.uint8)
for i, rindex in enumerate(range(0,800,100)):
    for j, cindex in enumerate(range(0,800,100)):
        if ((i%2 == 0 and j%2 == 0) or (i%2 != 0 and j%2 != 0)):
          white_canvas[rindex:rindex+100, cindex:cindex+100] = 0
plt.imshow(white_canvas)

# %% [markdown]
# ## Bitwise operations
#
# Bitwise operations are performed on an image when we need to extract only the required parts of the image. Consider a situation, in which we need to extract an irregular-shaped object from an image and paste it on another image. That’s exactly when we use bitwise operations on the image to separate the foreground from the background.
#
# When the mask parameter is set to a mask in the bitwise_and method, the AND operation is performed a bit differently than when the mask parameter is set to an empty array(default value). Masks can be created by performing thresholding on images.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img1 = np.zeros((1000,1000),dtype = np.int8)
cv2.rectangle(img1,(320,320),(680,680),255,-1)
plt.imshow(img1)

# %%
img2 = np.zeros((1000,1000),dtype = np.int8)
cv2.circle(img2,(500,500),200,255,-1)
plt.imshow(img2)

# %% [markdown]
# ### Bitwise AND
#
# A bitwise 'AND' is only 'True' when both inputs have a value that is 'ON' -- in this case, the cv2.bitwise_and function examines every pixel in the rectangle and circle; if *BOTH* pixels have a value greater than zero then the pixel is turned 'ON' (i.e., 255) in the output image; otherwise, the output value is set to 'OFF' (i.e., 0)

# %%
bitwiseAnd = cv2.bitwise_and(img1, img2)
plt.imshow(bitwiseAnd)

# %% [markdown]
# ### Bitwise OR
#
# A bitwise 'OR' examines every pixel in the two inputs, and if **EITHER** pixel in the rectangle or circle is greater than 0,then the output pixel has a value of 255, otherwise it is 0

# %%
bitwiseOR = cv2.bitwise_or(img1, img2)
plt.imshow(bitwiseOR)

# %% [markdown]
# ### Bitwise XOR
#
# The bitwise 'XOR' is identical to the 'OR' function, with one exception: the rectangle and circle are not allowed to **BOTH** have values greater than 0 (only one can be 0)

# %%
# Opposite to AND
bitwiseXOR = cv2.bitwise_xor(img1, img2)
plt.imshow(bitwiseXOR)

# %% [markdown]
# ### Bitwise NOT
#
# Finally, the bitwise 'NOT' inverts the values of the pixels; pixels with a value of 255 become 0, and pixels with a value of 0 become 255

# %%
# It takes only one input
bitwiseNOT = cv2.bitwise_not(img1)
plt.imshow(bitwiseNOT)

# %%
# Create inverse of an image
chess_gray_inv = cv2.bitwise_not(chess_gray)
plt.imshow(chess_gray_inv, cmap = 'gray')

# %% [markdown]
# ## Masking
#
# Masking is an extremely powerful and useful technique in computer vision and image processing.
#
# Using a mask allows us to focus only on the portions of the image that interests us.
# For example, let’s say that we were building a computer vision system to recognize faces. The only part of the image we are interested in finding and describing are the parts of the image that contain faces – we simply don’t care about the rest of the content of the image. Provided that we could find the faces in the image, we might construct a mask to show only the faces in the image.
# Let’s make this example a little more concrete.

# %%
image= cv2.imread('/content/drive/MyDrive/beach.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
mask = np.zeros(image.shape[:2], dtype = "uint8")
(cX, cY) = (image.shape[1] // 2, image.shape[0] // 2)
cv2.rectangle(mask, (cX - 75, cY - 75), (cX + 75 , cY + 75), 255,-1)
plt.imshow( mask)

# %%
masked = cv2.bitwise_and(image, image, mask = mask)
plt.imshow(masked)

# %%
# Only red component
opencv = cv2.imread('/content/drive/MyDrive/opencv_logo.png')
opencv = cv2.cvtColor(opencv, cv2.COLOR_BGR2RGB)
plt.imshow(opencv)

# %%
hsv = cv2.cvtColor(opencv, cv2.COLOR_RGB2HSV)
plt.imshow(hsv)

# %%
mask = cv2.inRange(hsv,np.array([0, 50,50]), np.array([10,255,255]))
plt.imshow(mask)

# %%
result = cv2.bitwise_and(opencv, opencv, mask=mask)
plt.imshow(result)

# %% [markdown]
# ## open-cv practice programs

# %% [markdown]
# ### 17.1 Python program to create a multi-coloured image using OpenCV.

# %%
import random
height = int(input("Enter the height of image (~100's):"))
width = int(input("Enter the width of image (~100's):"))
blocks = int(input("Enter how many color blocks you want ~(integer, divisor of both height and weight)"))
pixel_values = [0,50, 100, 150, 200, 255]
npi=np.full((height,width,3), (255,255,255),dtype=np.uint8)
for rindex in range(0,npi.shape[0], npi.shape[0]//blocks):
  for cindex in range(0,npi.shape[1], npi.shape[1]//blocks):
    npi[rindex:rindex+100, cindex:cindex+100] = (random.choice(pixel_values), random.choice(pixel_values), random.choice(pixel_values))
plt.imshow(npi)
# Out:
# Enter the height of image (~100's):800
# Enter the width of image (~100's):800
# Enter how many color blocks you want ~(integer, divisor of both height and weight)3

# %%
canvas = np.zeros((300, 300, 3), dtype = "uint8")
for i in range(0, 25):
    radius = np.random.randint(5, high = 200)
    color = np.random.randint(0, high = 256, size = (3,)).tolist()
    pt = np.random.randint(0, high = 300, size = (2,))
    cv2.circle(canvas, tuple(pt), radius, color, -1)
plt.imshow(canvas)

# %% [markdown]
# ### 17.2 Extracting Red Colour Channel from an Image and Converting the Remaining Channels to Black using OpenCV in Python

# %%
img = cv2.imread('/content/drive/MyDrive/opencv_logo.png')
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
mask = cv2.inRange(hsv,np.array([0, 50,50]), np.array([10,255,255]))
result = cv2.bitwise_and(opencv, opencv, mask=mask)
plt.imshow(result)

# %% [markdown]
# ### 17.3 Extracting green Colour Channel from an Image and Converting the Remaining Channels to Black using OpenCV in Python

# %%
img = cv2.imread('/content/drive/MyDrive/opencv_logo.png')
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
mask = cv2.inRange(hsv,np.array([45, 50, 50]), np.array([75, 255, 255]))
result = cv2.bitwise_and(opencv, opencv, mask=mask)
plt.imshow(result)

# %% [markdown]
# ### 17.4 Extracting blue Colour Channel from an Image and Converting the Remaining Channels to Black using OpenCV in Python

# %%
img = cv2.imread('/content/drive/MyDrive/opencv_logo.png')
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
mask = cv2.inRange(hsv,np.array([110, 50, 50]),np.array([130, 255, 255]))
result = cv2.bitwise_and(opencv, opencv, mask=mask)
plt.imshow(result)

# %% [markdown]
# ### 17.5 Converting Blue and Green Colour Channels to Black and Leaving Remaining Channels of the Image as Red using OpenCV in Python

# %%
img = cv2.imread('/content/drive/MyDrive/opencv_logo.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
r,g,b=cv2.split(img)
b[:] = 0
g[:] = 0
red_img=cv2.merge([r,g,b])
plt.imshow(red_img)

# %% [markdown]
# ### 17.6 Converting Blue and Red Colour Channels to Black and Leaving Remaining Channels of the Image as Green using OpenCV in Python

# %%
img = cv2.imread('/content/drive/MyDrive/opencv_logo.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
r,g,b=cv2.split(img)
r[:] = 0
b[:] = 0
green_img=cv2.merge([r,g,b])
plt.imshow(green_img)

# %% [markdown]
# ### 17.7 Converting Green and Red Colour Channels to Black and Leaving Remaining Channels of the Image as Blue using OpenCV in Python

# %%
img = cv2.imread('/content/drive/MyDrive/opencv_logo.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
r,g,b=cv2.split(img)
r[:] = 0
g[:] = 0
blue_img=cv2.merge([r,g,b])
plt.imshow(blue_img)
